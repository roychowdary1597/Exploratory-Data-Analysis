# %%
import pandas as pd
import numpy as np
import regex as re

# %%
df = pd.read_csv("EV_Database1_UK.csv")

# %%
df
# Out:
#                                         Brand  \
# 0               Tesla  Model Y Long Range AWD
# 1               Tesla  Model 3 Long Range AWD
# 2                         Kia  EV3 Long Range
# 3    Tesla  Model 3 RWD (Highland CATL LFP64)
# 4                Tesla  Model Y RWD (Juniper)
# ..                                        ...
# 741                Tesla  Model X Performance
# 742                        Kia  e-Niro 39 kWh
# 743                   Smart  EQ fortwo cabrio
# 744      Peugeot  e-Traveller Standard 50 kWh
# 745         Audi  e-tron Sportback 50 quattro
#
#                               Availability_Status Efficiency    Weight  \
# 0    Discontinued (February 2022 - February 2025)  273 Wh/mi  2,054 kg
# 1     Discontinued (February 2022 - October 2023)  250 Wh/mi  1,919 kg
# 2           Available to order since October 2024  279 Wh/mi  1,885 kg
# 3               Available to order since May 2025  220 Wh/mi  1,836 kg
# ...

# %%
df.head()
# Out:
#                                       Brand  \
# 0             Tesla  Model Y Long Range AWD
# 1             Tesla  Model 3 Long Range AWD
# 2                       Kia  EV3 Long Range
# 3  Tesla  Model 3 RWD (Highland CATL LFP64)
# 4              Tesla  Model Y RWD (Juniper)
#
#                             Availability_Status Efficiency    Weight  \
# 0  Discontinued (February 2022 - February 2025)  273 Wh/mi  2,054 kg
# 1   Discontinued (February 2022 - October 2023)  250 Wh/mi  1,919 kg
# 2         Available to order since October 2024  279 Wh/mi  1,885 kg
# 3             Available to order since May 2025  220 Wh/mi  1,836 kg
# 4        Available to order since February 2025  257 Wh/mi  2,003 kg
#
#   Accleration Battery_Capacity  Seating_Capacity Boot Space Price_Per_Range  \
# 0     5.0 sec         75.0 kWh                 7      971 L        £189 /mi
# 1     4.4 sec         75.0 kWh                 5      649 L        £170 /mi
# ...

# %%
df.tail()
# Out:
#                                     Brand  \
# 741            Tesla  Model X Performance
# 742                    Kia  e-Niro 39 kWh
# 743               Smart  EQ fortwo cabrio
# 744  Peugeot  e-Traveller Standard 50 kWh
# 745     Audi  e-tron Sportback 50 quattro
#
#                               Availability_Status Efficiency    Weight  \
# 741          Discontinued (March 2019 - May 2019)  365 Wh/mi  2,572 kg
# 742      Discontinued (July 2020 - December 2020)  270 Wh/mi  1,667 kg
# 743    Discontinued (April 2018 - September 2019)  304 Wh/mi  1,115 kg
# 744       Discontinued (June 2021 - January 2024)  403 Wh/mi  1,969 kg
# 745  Discontinued (October 2021 - September 2022)  359 Wh/mi  2,445 kg
#
#     Accleration Battery_Capacity  Seating_Capacity Boot Space Price_Per_Range  \
# 741     3.7 sec         95.0 kWh                 7    unknown        £346 /mi
# 742     9.8 sec         39.2 kWh                 5      451 L        £204 /mi
# ...

# %%
df.loc[3:]
# Out:
#                                         Brand  \
# 3    Tesla  Model 3 RWD (Highland CATL LFP64)
# 4                Tesla  Model Y RWD (Juniper)
# 5                       MG  MG4 EV Long Range
# 6           BYD  SEAL 82.5 kWh AWD Excellence
# 7               Renault  5 E-Tech 52kWh 150hp
# ..                                        ...
# 741                Tesla  Model X Performance
# 742                        Kia  e-Niro 39 kWh
# 743                   Smart  EQ fortwo cabrio
# 744      Peugeot  e-Traveller Standard 50 kWh
# 745         Audi  e-tron Sportback 50 quattro
#
#                               Availability_Status Efficiency    Weight  \
# 3               Available to order since May 2025  220 Wh/mi  1,836 kg
# 4          Available to order since February 2025  257 Wh/mi  2,003 kg
# 5           Available to order since October 2022  274 Wh/mi  1,726 kg
# 6         Available to order since September 2023  300 Wh/mi  2,260 kg
# ...

# %%
df.iloc[3:]
# Out:
#                                         Brand  \
# 3    Tesla  Model 3 RWD (Highland CATL LFP64)
# 4                Tesla  Model Y RWD (Juniper)
# 5                       MG  MG4 EV Long Range
# 6           BYD  SEAL 82.5 kWh AWD Excellence
# 7               Renault  5 E-Tech 52kWh 150hp
# ..                                        ...
# 741                Tesla  Model X Performance
# 742                        Kia  e-Niro 39 kWh
# 743                   Smart  EQ fortwo cabrio
# 744      Peugeot  e-Traveller Standard 50 kWh
# 745         Audi  e-tron Sportback 50 quattro
#
#                               Availability_Status Efficiency    Weight  \
# 3               Available to order since May 2025  220 Wh/mi  1,836 kg
# 4          Available to order since February 2025  257 Wh/mi  2,003 kg
# 5           Available to order since October 2022  274 Wh/mi  1,726 kg
# 6         Available to order since September 2023  300 Wh/mi  2,260 kg
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 746 entries, 0 to 745
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Brand                746 non-null    object
#  1   Availability_Status  746 non-null    object
#  2   Efficiency           746 non-null    object
#  3   Weight               746 non-null    object
#  4   Accleration          746 non-null    object
#  5   Battery_Capacity     746 non-null    object
#  6   Seating_Capacity     746 non-null    int64
#  7   Boot Space           746 non-null    object
#  8   Price_Per_Range      746 non-null    object
#  9   Model Price          746 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 58.4+ KB

# %%
df.describe()
# Out:
#        Seating_Capacity
# count        746.000000
# mean           5.171582
# std            0.976253
# min            2.000000
# 25%            5.000000
# 50%            5.000000
# 75%            5.000000
# max            9.000000

# %%
df.shape
# Out:
# (746, 10)

# %%
df.dtypes
# Out:
# Brand                  object
# Availability_Status    object
# Efficiency             object
# Weight                 object
# Accleration            object
# Battery_Capacity       object
# Seating_Capacity        int64
# Boot Space             object
# Price_Per_Range        object
# Model Price            object
# dtype: object
